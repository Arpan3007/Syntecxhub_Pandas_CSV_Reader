# %%
import pandas as pd

# %% [markdown]
# ## **Loaded CSV files**

# %%
athletes = pd.read_csv("athlete_events.csv") 
noc = pd.read_csv("noc_regions.csv")

# %% [markdown]
# ## **Merged datasets**

# %%
merged_df = athletes.merge(noc, on="NOC", how="left")
merged_df = merged_df.rename(columns={"region": "Country"})

# %% [markdown]
# ## **inspect head/tail/types**

# %%
merged_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal      Country notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
merged_df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal Country notes
# ...

# %%
merged_df.dtypes
# Out:
# ID           int64
# Name        object
# Sex         object
# Age        float64
# Height     float64
# Weight     float64
# Team        object
# NOC         object
# Games       object
# Year         int64
# Season      object
# City        object
# Sport       object
# Event       object
# Medal       object
# Country     object
# notes       object
# dtype: object

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       271116 non-null  int64
#  1   Name     271116 non-null  object
#  2   Sex      271116 non-null  object
#  3   Age      261642 non-null  float64
#  4   Height   210945 non-null  float64
#  5   Weight   208241 non-null  float64
#  6   Team     271116 non-null  object
#  7   NOC      271116 non-null  object
#  8   Games    271116 non-null  object
#  9   Year     271116 non-null  int64
#  10  Season   271116 non-null  object
#  11  City     271116 non-null  object
#  12  Sport    271116 non-null  object
#  13  Event    271116 non-null  object
#  14  Medal    39783 non-null   object
#  15  Country  270746 non-null  object
#  16  notes    5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.2+ MB

# %% [markdown]
# ## **Summary statistics**

# %%
merged_df.mean(numeric_only=True)
# Out:
# ID        68248.954396
# Age          25.556898
# Height      175.338970
# Weight       70.702393
# Year       1978.378480
# dtype: float64

# %%
merged_df.median(numeric_only=True)
# Out:
# ID        68205.0
# Age          24.0
# Height      175.0
# Weight       70.0
# Year       1988.0
# dtype: float64

# %%
merged_df.min(numeric_only=True)
# Out:
# ID           1.0
# Age         10.0
# Height     127.0
# Weight      25.0
# Year      1896.0
# dtype: float64

# %%
merged_df.max(numeric_only=True)
# Out:
# ID        135571.0
# Age           97.0
# Height       226.0
# Weight       214.0
# Year        2016.0
# dtype: float64

# %%
merged_df.count()
# Out:
# ID         271116
# Name       271116
# Sex        271116
# Age        261642
# Height     210945
# Weight     208241
# Team       271116
# NOC        271116
# Games      271116
# Year       271116
# Season     271116
# City       271116
# Sport      271116
# Event      271116
# Medal       39783
# Country    270746
# notes        5039
# dtype: int64

# %% [markdown]
# ## **Filtering operations**

# %%
age_filter = merged_df[merged_df["Age"] > 30]
age_filter.head()
# Out:
#     ID                  Name Sex   Age  Height  Weight            Team  NOC  \
# 3    4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 10   6       Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
# 11   6       Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
# 12   6       Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
# 13   6       Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 3   1900 Summer  1900  Summer        Paris            Tug-Of-War
# 10  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 11  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 12  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 13  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                                 Event Medal  Country notes
# ...

# %%
medal_winners = merged_df[merged_df["Medal"].notna()]
medal_winners.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal  Country notes
# 3              Tug-Of-War Men's Tug-Of-War    Gold  Denmark   NaN
# ...

# %%
subset = merged_df[["Name", "Age", "Sex", "Sport", "Country"]]
subset.head()
# Out:
#                        Name   Age Sex          Sport      Country
# 0                 A Dijiang  24.0   M     Basketball        China
# 1                  A Lamusi  23.0   M           Judo        China
# 2       Gunnar Nielsen Aaby  24.0   M       Football      Denmark
# 3      Edgar Lindenau Aabye  34.0   M     Tug-Of-War      Denmark
# 4  Christine Jacoba Aaftink  21.0   F  Speed Skating  Netherlands

# %%
slice_data = merged_df.iloc[0:10]
slice_data
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %% [markdown]
# ## **Saved output files**

# %%
age_filter.to_excel("outputs/age_above_30.xlsx", index=False)

# %%
medal_winners.to_excel("outputs/medal_winners.xlsx", index=False)

# %%
subset.to_excel("outputs/subset_output.xlsx", index=False)

# %%
slice_data.to_excel("outputs/slice_data.xlsx", index=False)
